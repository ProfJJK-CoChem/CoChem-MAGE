# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE")
tests_dir = module_dir / "tests"

print(f"[CoChem-MAGE] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-MAGE.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-MAGE] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE
# configfile: pyproject.toml
# plugins: anyio-4.10.0
# collecting ... collected 96 items
#
# tests/test_adversarial_m7_fuzz.py::test_exporter_interactive_chromatogram_fuzz PASSED [  1%]
# tests/test_adversarial_m7_fuzz.py::test_exporter_scribe_payload_fuzz PASSED [  2%]
# tests/test_adversarial_m7_fuzz.py::test_exporter_head_to_tail_ms_plot_fuzz PASSED [  3%]
# tests/test_adversarial_m7_fuzz.py::test_exporter_parquet_export_fuzz PASSED [  4%]
# tests/test_adversarial_m7_fuzz.py::test_opt_tpgc_peak_width_extreme_fuzz PASSED [  5%]
# tests/test_adversarial_m7_fuzz.py::test_opt_objective_function_extreme_fuzz PASSED [  6%]
# tests/test_adversarial_m7_fuzz.py::test_opt_optimize_separation_disaster_scenarios PASSED [  7%]
# tests/test_adversarial_m7_fuzz.py::test_sim_determine_product_class_precedence_and_types PASSED [  8%]
# tests/test_adversarial_m7_fuzz.py::test_sim_chi_indices_invalid_inputs PASSED [  9%]
# tests/test_adversarial_m7_fuzz.py::test_sim_van_deemter_hetp_extreme_params PASSED [ 10%]
# tests/test_adversarial_m7_fuzz.py::test_sim_massive_job_queue_performance PASSED [ 11%]
# tests/test_adversarial_m7_fuzz.py::test_kovats_ri_math_functions_boundary_cases PASSED [ 12%]
# tests/test_adversarial_m7_fuzz.py::test_halogen_isotope_generator_fuzz PASSED [ 13%]
# tests/test_adversarial_m7_fuzz.py::test_fragmenter_invalid_smiles_and_graphs PASSED [ 14%]
# tests/test_adversarial_m7_fuzz.py::test_fragmenter_rrkm_beyer_swinehart_rate_bounds PASSED [ 15%]
# tests/test_adversarial_m7_fuzz.py::test_graph_builder_none_mol_raises PASSED [ 16%]
# tests/test_adversarial_m7_fuzz.py::test_dag_compiler_non_dict_and_provenance_tags PASSED [ 17%]
# tests/test_adversarial_m7_fuzz.py::test_orchestrator_uninitialized_and_h5_export PASSED [ 18%]
# tests/test_adversarial_m7_fuzz.py::test_telemetry_bridge_thread_safety_and_none_values PASSED [ 19%]
# tests/test_adversarial_m7_fuzz.py::test_descriptor_cache_sqlite_operations PASSED [ 20%]
# tests/test_adversarial_m7_fuzz.py::test_ingestor_nist_api_failover PASSED [ 21%]
# tests/test_challenger_m7_empirical.py::TestFocalArea1ConfigAndDirs::test_config_sanitization_legacy_methods PASSED [ 22%]
# tests/test_challenger_m7_empirical.py::TestFocalArea1ConfigAndDirs::test_config_missing_parent_directory_creation PASSED [ 23%]
# tests/test_challenger_m7_empirical.py::TestFocalArea1ConfigAndDirs::test_orchestrator_directory_creation PASSED [ 25%]
# tests/test_challenger_m7_empirical.py::TestFocalArea2ProductClassPrecedence::test_product_class_a_default PASSED [ 26%]
# tests/test_challenger_m7_empirical.py::TestFocalArea2ProductClassPrecedence::test_product_class_b_measured_parent PASSED [ 27%]
# tests/test_challenger_m7_empirical.py::TestFocalArea2ProductClassPrecedence::test_product_class_c_difference_calc PASSED [ 28%]
# tests/test_challenger_m7_empirical.py::TestFocalArea2ProductClassPrecedence::test_product_class_precedence_c_over_b PASSED [ 29%]
# tests/test_challenger_m7_empirical.py::TestFocalArea2ProductClassPrecedence::test_product_class_non_dict_safety PASSED [ 30%]
# tests/test_challenger_m7_empirical.py::TestFocalArea3VanDeemterGuards::test_negative_and_zero_velocity PASSED [ 31%]
# tests/test_challenger_m7_empirical.py::TestFocalArea3VanDeemterGuards::test_extreme_high_velocity PASSED [ 32%]
# tests/test_challenger_m7_empirical.py::TestFocalArea3VanDeemterGuards::test_none_keys_in_station_phase_params PASSED [ 33%]
# tests/test_challenger_m7_empirical.py::TestFocalArea3VanDeemterGuards::test_singular_retention_factor PASSED [ 34%]
# tests/test_challenger_m7_empirical.py::TestFocalArea3VanDeemterGuards::test_zero_diffusion_constants PASSED [ 35%]
# tests/test_challenger_m7_empirical.py::TestFocalArea4DAGCompilerNodeOrderAndTags::test_dag_compiler_step_order_and_provenance_tags PASSED [ 36%]
# tests/test_challenger_m7_empirical.py::TestFocalArea4DAGCompilerNodeOrderAndTags::test_dag_compiler_dependency_edges PASSED [ 37%]
# tests/test_challenger_m7_empirical.py::TestFocalArea5TelemetryAndHDF5Export::test_consecutive_hdf5_exports_no_collision PASSED [ 38%]
# tests/test_challenger_m7_empirical.py::TestFocalArea5TelemetryAndHDF5Export::test_telemetry_bridge_state_updates_and_provenance_tags PASSED [ 39%]
# tests/test_mage.py::test_orchestrator_init PASSED                        [ 40%]
# tests/test_mage.py::test_orchestrator_sim PASSED                         [ 41%]
# tests/test_mage.py::test_chromatography_sim PASSED                       [ 42%]
# tests/test_mage.py::test_optimization_engine PASSED                      [ 43%]
# tests/test_mage.py::test_isotope_generator PASSED                        [ 44%]
# tests/test_mage.py::test_graph_builder PASSED                            [ 45%]
# tests/test_mage.py::test_fragmenter PASSED                               [ 46%]
# tests/test_mage.py::test_abraham_stationary_phase_partitioning PASSED    [ 47%]
# tests/test_mage.py::test_van_deemter_and_kovats_ri PASSED                [ 48%]
# tests/test_mage.py::test_mage_exporter_head_to_tail_and_parquet PASSED   [ 50%]
# tests/test_mage.py::test_v4_config_defaults PASSED                       [ 51%]
# tests/test_mage.py::test_product_class_decision_tree PASSED              [ 52%]
# tests/test_mage.py::test_spend_priority_dag_compiler PASSED              [ 53%]
# tests/test_mage.py::test_phase_grounded_golay_hetp PASSED                [ 54%]
# tests/test_mage.py::test_provenance_tagging_across_modules PASSED        [ 55%]
# tests/test_mage.py::test_config_sanitization_and_saving PASSED           [ 56%]
# tests/test_mage.py::test_hdf5_consecutive_export_no_collision PASSED     [ 57%]
# tests/test_mage.py::test_determine_product_class_robustness_and_precedence PASSED [ 58%]
# tests/test_mage.py::test_van_deemter_hetp_boundary_guards PASSED         [ 59%]
# tests/test_mage.py::test_tpgc_peak_width_boundary_guards PASSED          [ 60%]
# tests/test_mage.py::test_parquet_and_dag_compiler_input_guards PASSED    [ 61%]
# tests/test_mage.py::test_fragmenter_invalid_smiles_and_none_graph PASSED [ 62%]
# tests/test_stress_m7_deep.py::test_config_sanitization_legacy_overrides PASSED [ 63%]
# tests/test_stress_m7_deep.py::test_config_missing_parent_directory_creation PASSED [ 64%]
# tests/test_stress_m7_deep.py::test_config_sanitize_non_dict_input PASSED [ 65%]
# tests/test_stress_m7_deep.py::test_product_class_non_dict_type_safety PASSED [ 66%]
# tests/test_stress_m7_deep.py::test_product_class_precedence_isotopologue_difference PASSED [ 67%]
# tests/test_stress_m7_deep.py::test_product_class_standard_routing PASSED [ 68%]
# tests/test_stress_m7_deep.py::test_van_deemter_hetp_none_parameters PASSED [ 69%]
# tests/test_stress_m7_deep.py::test_van_deemter_hetp_singular_retention_factor PASSED [ 70%]
# tests/test_stress_m7_deep.py::test_van_deemter_hetp_negative_and_extreme_velocities PASSED [ 71%]
# tests/test_stress_m7_deep.py::test_randic_connectivity_invalid_smiles PASSED [ 72%]
# tests/test_stress_m7_deep.py::test_abraham_solvation_extreme_descriptors PASSED [ 73%]
# tests/test_stress_m7_deep.py::test_build_chromatogram_empty_and_null_jobs PASSED [ 75%]
# tests/test_stress_m7_deep.py::test_kovats_ri_math_functions PASSED       [ 76%]
# tests/test_stress_m7_deep.py::test_tpgc_peak_width_boundary_guards PASSED [ 77%]
# tests/test_stress_m7_deep.py::test_optimization_co_eluting_isomers_disaster_recovery PASSED [ 78%]
# tests/test_stress_m7_deep.py::test_optimization_single_or_empty_job_queue PASSED [ 79%]
# tests/test_stress_m7_deep.py::test_optimization_successful_convergence PASSED [ 80%]
# tests/test_stress_m7_deep.py::test_fragmenter_invalid_smiles_and_none_graph PASSED [ 81%]
# tests/test_stress_m7_deep.py::test_fragmenter_beyer_swinehart_rrkm_bounds PASSED [ 82%]
# tests/test_stress_m7_deep.py::test_fragmenter_valid_benzene_spectrum PASSED [ 83%]
# tests/test_stress_m7_deep.py::test_graph_builder_none_mol_raises PASSED  [ 84%]
# tests/test_stress_m7_deep.py::test_graph_builder_chlorobenzene_tensor PASSED [ 85%]
# tests/test_stress_m7_deep.py::test_spend_priority_dag_compiler_non_dict PASSED [ 86%]
# tests/test_stress_m7_deep.py::test_parquet_export_empty_and_null_job_queue PASSED [ 87%]
# tests/test_stress_m7_deep.py::test_interactive_chromatogram_rendering PASSED [ 88%]
# tests/test_stress_m7_deep.py::test_head_to_tail_ms_plot_dict_spectra PASSED [ 89%]
# tests/test_stress_m7_deep.py::test_head_to_tail_ms_plot_empty_list_unhandled_exception PASSED [ 90%]
# tests/test_stress_m7_deep.py::test_orchestrator_uninitialized_simulation_raises PASSED [ 91%]
# tests/test_stress_m7_deep.py::test_orchestrator_concurrent_hdf5_writes PASSED [ 92%]
# tests/test_stress_m7_deep.py::test_orchestrator_full_simulation_flow PASSED [ 93%]
# tests/test_stress_m7_deep.py::test_telemetry_bridge_thread_safety PASSED [ 94%]
# tests/test_stress_m7_deep.py::test_descriptor_cache_sqlite PASSED        [ 95%]
# tests/test_stress_m7_deep.py::test_parquet_export_type_and_element_guards PASSED [ 96%]
# tests/test_stress_m7_deep.py::test_optimization_active_matrix_none_element_guard PASSED [ 97%]
# tests/test_stress_m7_deep.py::test_run_simulation_none_input_data_guard PASSED [ 98%]
# tests/test_stress_m7_deep.py::test_get_full_isotope_cluster_none_formula_dict_guard PASSED [100%]
#
# ============================= 96 passed in 9.69s ==============================
#
# ✅ Genuine Native Execution Complete.
